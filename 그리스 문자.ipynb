# %% [markdown]
# # 그리스 문자

# %% [markdown]
# ## 그리스 문자 기호 및 읽는 방법

# %%
a = pd.read_csv('./number/1.csv', encoding='utf-8')
a
# Out:
#    알파벳 대문자 알파벳 소문자   영어 표기법 한글 표기법            주의점
# 0        A       α    alpha     알파  영어 a와 다르므로 주의
# 1        B       β     beta     베타  영어 b와 다르므로 주의
# 2        Γ       γ    gamma     감마  영어 r과 다르므로 주의
# 3        Δ       δ    delta     델타            NaN
# 4        E       ϵ  epsilon    엡실론  영어 e와 다르므로 주의
# 5        Z       ζ     zeta     제타            NaN
# 6        H       η      eta     에타            NaN
# 7        Θ       θ    theta     쎄타            NaN
# 8        K       κ    kappa     카파  영어 k와 다르므로 주의
# 9        Λ       λ   lambda     람다            NaN
# 10       M       μ       mu      뮤            NaN
# 11       N       ν       nu      누  영어 v와 다르므로 주의
# 12       Ξ       ξ       xi    크싸이            NaN
# 13       Π       π       pi     파이            NaN
# 14       P       ρ      rho      로  영어 p와 다르므로 주의
# 15       Σ       σ    sigma    시그마  숫자 6과 다르므로 주의
# 16       T       τ      tau     타우  영어 t와 다르므로 주의
# 17       Φ       ϕ      phi   파이/피            NaN
# ...

# %% [markdown]
# ## 그리스 문자 쓰는 방법

# %% [markdown]
# - "$\alpha$와 $\beta$의 값이 같다."를 작성 하고 싶으면 아래와 같이 입력해야 한다.
# ```
# $\alpha$와 $\beta$의 값이 같다.
# ```

# %% [markdown]
# - $$ \alpha = \beta $$를 작성 하고 싶으면 아래와 같이 입력해야 한다.
# ```
# $$ \alpha = \beta $$
# ```
